# %% [markdown]
# # Government Crisis Response to COVID-19
#
# We are trying to find the impact of the govt. crisis response specifically in regions and countries like Bangladesh, Ethiopia, Guatemala, Kenya, Nepal, Pakistan, Uganda, etc. We are studying third world countries here, where COVID control posed a real challenge for the governments.

# %% [markdown]
# Importing Libraries and Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Dataset link: https://www.acaps.org/covid-19-government-measures-dataset

df = pd.read_excel('acaps.xlsx')

# %% [markdown]
# ## About the dataset
# The COVID-19 Government Measures Dataset puts together all the measures implemented by governments worldwide in response to the Coronavirus pandemic. Data collection includes secondary data review. The researched information available falls into five categories:
#
# - Social distancing
# - Movement restrictions
# - Public health measures
# - Social and economic measures
# - Lockdowns
#
# Each category is broken down into several types of measures.

# %%
df.head()
# Out:
#      ID  ISO  ... ENTRY_DATE Alternative source
# 0  4245  AFG  ... 2020-04-07                NaN
# 1  4246  AFG  ... 2020-04-07                NaN
# 2  4247  AFG  ... 2020-04-07                NaN
# 3  4248  AFG  ... 2020-04-07                NaN
# 4    23  AFG  ... 2020-03-14                NaN
#
# [5 rows x 18 columns]

# %% [markdown]
# Dropping data columns we won't use for our findings

# %%
df = df.drop(columns=['ID', 'ISO', 'ADMIN_LEVEL_NAME', 'PCODE', 'TARGETED_POP_GROUP', 'COMMENTS', 'NON_COMPLIANCE', 'LINK', 'ENTRY_DATE', 'Alternative source'])

# %%
df.head()
# Out:
#        COUNTRY REGION  ...            SOURCE SOURCE_TYPE
# 0  Afghanistan   Asia  ...  Afghanistan MoPH  Government
# 1  Afghanistan   Asia  ...  Afghanistan MoPH  Government
# 2  Afghanistan   Asia  ...  Afghanistan MoPH  Government
# 3  Afghanistan   Asia  ...  Afghanistan MoPH  Government
# 4  Afghanistan   Asia  ...       US Embassy   Government
#
# [5 rows x 8 columns]

# %%
# Specifying the list of countries to be used in our study

countries = ['Afghanistan', 'Bangladesh', 'Benin', 'Burkina Faso', 'Ethiopia', 'Ghana', 'Guatemala', 'Kenya', 'Mali', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nigeria', 'Pakistan', 'Philippines', 'Rwanda', 'Senegal', 'South Africa', 'Tanzania', 'Togo', 'Uganda', 'Ukraine' 'Zambia']

# %%
# Filtering out only the relevant countries' data from the dataset

df = df.loc[df['COUNTRY'].isin(countries)]

# %% [markdown]
# Let's have a look on the type of measures implemented and how they were circulated among the people

# %%
df['MEASURE'].value_counts().plot(kind='barh')

# %%
df['CATEGORY'].value_counts().plot(kind='barh')

# %% [markdown]
# It can be noticed that a lot of economic measures were taken by these countries with respect to public health, followed by restrictions on movement and social distancing. It is worth noticing that lockdown was not the most favourite measure in third world countries in contrast to developed countries. This is due to the fact that the economy of these countries rely heavily on daily productivity, and we can assume that these countries usually locked down places where and only when the no. of cases racked up.

# %%
df['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %% [markdown]
# The above bar graph shows the source/medium by which these meaures were circulated among the people. We can see that the governments in these countries was actively involved in this, followed by the use of mass media and social media.
#
# Let us now study individual countries for more insights.

# %%
cn = df.loc[df['COUNTRY'].isin(['Bangladesh'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Bangladesh'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Ghana'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Burkina Faso'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Ethiopia'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Ethiopia'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Guatemala'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Guatemala'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Kenya'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Kenya'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Nepal'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Nepal'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Nigeria'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Nigeria'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Pakistan'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Pakistan'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['South Africa'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['South Africa'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Uganda'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Uganda'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Tanzania'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Tanzania'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Mali'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Afghanistan'])]
cn['MEASURE'].value_counts().plot(kind='barh')

# %%
cn = df.loc[df['COUNTRY'].isin(['Afghanistan'])]
cn['SOURCE_TYPE'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Observation
#
# Countries like Ethiopia, Bangladesh, Guatemela have suffered from severe spread of COVID-19. Relied heavily on curfews and travel restrictions and less on strengthening the public health system and monitoring, suffering the consequences.
#
# Nigeria and Ghana did well in controlling the surge towards the end of 2020 once they started implementing health measures.
#
# Kenya and Afghanistan showed decent fight against COVID. Once more, public health strengthening and economic measures helped their cause.
#
# Nepal and South Africa brought down their COVID cases massively with similar measures and interestingly, the heavy use of media and social media. Same goes for Uganda, who did well considering they've more than twice the population of Guatemala.
#
# Tanzania declared themselves COVID free from June 2020 and have now also rejected the vaccine. With a population of 58 million, that is impressive, and once more they've made heavy use of media to support their cause.
#
# So, we could observe from this data, how using the right measures with awareness spread through multiple mediums can better aid the COVID-19 control in these countries.
